# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from clf_funcs import setup, PerfCounterCallback, env_builder

import pandas as pd
import numpy as np

import tensorflow as tf
from tqdm import trange

INDEX = 3

# %%
from time import perf_counter_ns


def combine_model(inputs, predef_model, classifier, image_size=32):
	predef_model_materialised = predef_model(
		input_shape=(image_size, image_size, 3),
		include_top=False,
		weights=None
	)

	# resize = tf.keras.layers.Resizing(image_size, image_size)(inputs)

	feature_extractor = predef_model_materialised(inputs)
	classification_output = classifier(feature_extractor)
	combined = tf.keras.Model(inputs=inputs, outputs=classification_output)

	return combined


def classifier_overlay(inputs):
	x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
	x = tf.keras.layers.Flatten()(x)
	x = tf.keras.layers.Dense(10, activation="softmax", name="classification")(x)
	return x


class FullyConnectedNet(tf.keras.Model):

	def __init__(self, hidden_layers=[800], num_classes=10):
		super().__init__()
		self.hidden_layers = tf.keras.Sequential([
			tf.keras.layers.Dense(n, activation=tf.nn.relu) for n in hidden_layers
		])
		self.output_layer = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax)

	def call(self, x):
		x = self.hidden_layers(x)
		return self.output_layer(x)


def SimpleConvNetBuilder(num_classes=10):
	layers = [
		tf.keras.Input(shape=(28, 28, 1)),
		tf.keras.layers.Conv2D(16, kernel_size=5, padding="same", activation='relu'),
		tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
		tf.keras.layers.Conv2D(32, kernel_size=5, padding="same", activation='relu'),
		tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
		tf.keras.layers.Flatten(),
		tf.keras.layers.Dense(512, activation='relu'),
		tf.keras.layers.Dense(num_classes, activation='softmax'),
	]
	return tf.keras.Sequential(layers)


def get_cifar10_data(preprocess=None):
	(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
	x_train, x_test = x_train.astype('float32'), x_test.astype('float32')

	if preprocess is not None:
		x_train, x_test = preprocess(x_train), preprocess(x_test)

	return (x_train, y_train), (x_test, y_test)


def load_mnist_imgs_and_labels(imgs_path, labels_path) -> tuple[np.ndarray, np.ndarray]:
	i_hand = open(imgs_path, 'rb')
	l_hand = open(labels_path, 'rb')

	i_hand.seek(4, 0) # skipping "magic" numbers
	l_hand.seek(4, 0)

	n_imgs = int.from_bytes(i_hand.read(4), 'big')

	imgs = np.frombuffer(i_hand.read(), np.uint8, offset=8)
	imgs = (255 - imgs) / 255
	imgs = imgs.reshape(n_imgs, 28 * 28)

	labels = np.frombuffer(l_hand.read(), np.uint8, offset=4)

	i_hand.close()
	l_hand.close()

	return imgs, labels


def get_mnist_loaders(batch_size, test_batch_size=None, flatten=True):
	if not test_batch_size: test_batch_size = batch_size * 2

	x_train, y_train = load_mnist_imgs_and_labels(
		'./drive/MyDrive/colab/datasets/mnist-digits/train-images-idx3-ubyte',
		'./drive/MyDrive/colab/datasets/mnist-digits/train-labels-idx1-ubyte'
	)

	x_test, y_test = load_mnist_imgs_and_labels(
		'./drive/MyDrive/colab/datasets/mnist-digits/t10k-images-idx3-ubyte',
		'./drive/MyDrive/colab/datasets/mnist-digits/t10k-labels-idx1-ubyte'
	)

	if not flatten:
		x_train, x_test = map(
			lambda x: x.reshape(-1, 28, 28, 1),
			(x_train, x_test)
		)

	train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
	train_ds = train_ds.shuffle(buffer_size=1024).batch(batch_size)

	test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
	test_ds = test_ds.batch(test_batch_size)

	return train_ds, test_ds


def env_builder(name, config):
	if name == 'FullyConnectedNet':
		model = FullyConnectedNet()
		train_ds, test_ds = get_mnist_loaders(config['batch_size'], config['test_batch_size'])
	elif name == 'SimpleConvNet':
		model = SimpleConvNetBuilder()
		train_ds, test_ds = get_mnist_loaders(config['batch_size'], config['test_batch_size'], flatten=False)
	elif name == 'ResNet-50':
		model = combine_model(config['inputs'], tf.keras.applications.ResNet50, classifier_overlay)
		train_ds, test_ds = get_cifar10_data(tf.keras.applications.resnet50.preprocess_input)
	elif name == 'DenseNet-121':
		model = combine_model(config['inputs'], tf.keras.applications.DenseNet121, classifier_overlay)
		train_ds, test_ds = get_cifar10_data(tf.keras.applications.densenet.preprocess_input)
	elif name == 'MobileNet-v2':
		model = combine_model(config['inputs'], tf.keras.applications.MobileNetV2, classifier_overlay)
		train_ds, test_ds = get_cifar10_data(tf.keras.applications.mobilenet_v2.preprocess_input)
	elif name == 'ConvNeXt-Tiny':
		model = combine_model(config['inputs'], tf.keras.applications.ConvNeXtTiny, classifier_overlay)
		train_ds, test_ds = get_cifar10_data(tf.keras.applications.convnext.preprocess_input)
	else:
		raise ValueError('Invalid model name')

	return model, train_ds, test_ds


class PerfCounterCallback(tf.keras.callbacks.Callback):
	def __init__(self, telemetry_ref: dict, latency_ref: list[int]):
		super().__init__()
		self.telemetry_ref = telemetry_ref
		self.latency_ref = latency_ref
		self.times = []
		self.eps = []
		self.training = False

	# for training
	def on_train_begin(self, logs=None):
		self.training = True

	def on_epoch_begin(self, epoch, logs=None):
		self.ep_start = perf_counter_ns()

	def on_epoch_end(self, epoch, logs=None):
		self.times.append(perf_counter_ns() - self.ep_start)
		self.eps.append(epoch + 1)

	def on_train_end(self, logs=None):
		self.telemetry_ref['epoch'].extend(self.eps)
		self.telemetry_ref['elapsed_time'].extend(self.times)
		self.training = False

	# for evaluation
	def on_test_begin(self, logs=None):
		self.test_start = perf_counter_ns()

	def on_test_end(self, logs=None):
		if self.training: return
		self.telemetry_ref['elapsed_time'].append(perf_counter_ns() - self.test_start)
		self.telemetry_ref['epoch'].append(1)

	def on_predict_begin(self, logs=None):
		self.pred_start = perf_counter_ns()


	def on_predict_end(self, logs=None):
		pred_end = perf_counter_ns()
		self.latency_ref.append(pred := (pred_end - self.pred_start))

# %%
telemetry = {
	'framework': [],
	'model_name': [],
	'rep': [],
	'batch_size': [],
	'elapsed_time': []
}

warmup_steps = 100
repetitions = 50
perf_callback = PerfCounterCallback(None, [])

config = {
	'batch_size': 1,
	'test_batch_size': 1,
	'inputs': tf.keras.layers.Input(shape=(32,32,3)),
}

# %%
second_run = False

if second_run:
	models = ['MobileNet-v2', 'ConvNeXt-Tiny']
else:
	# models = ['FullyConnectedNet', 'SimpleConvNet', 'ResNet-50', 'DenseNet-121']
	models = ['FullyConnectedNet', 'SimpleConvNet', 'ResNet-50', 'DenseNet-121', 'MobileNet-v2', 'ConvNeXt-Tiny']

for model_name in models:
	for batch_size in [1, 16, 32, 64, 96, 128, 192, 256]:
		config["batch_size"] = batch_size
		model, ds, _ = env_builder(model_name, config)

		if isinstance(ds, tuple):
			sample = ds[0][:batch_size]
			sample = tf.convert_to_tensor(sample, dtype=tf.float32)
		else:
			sample = next(iter(ds))[0]

		# model.predict(batch_size=None) =================================================
		for i in trange(warmup_steps, desc=f"Warmup for {model_name} (batch of {batch_size})"):
			_ = model.predict(sample, verbose=0, batch_size=None)

		perf_callback.latency_ref.clear()
		for i in trange(repetitions, desc=f"Predict without bsize for {model_name} (batch of {batch_size})"):
			_ = model.predict(sample, verbose=0, callbacks=[perf_callback], batch_size=None)

			telemetry['framework'].append("TF (batch_size=None)")
			telemetry['model_name'].append(model_name)
			telemetry['rep'].append(i)
			telemetry['batch_size'].append(batch_size)
		telemetry['elapsed_time'].extend(perf_callback.latency_ref)

		# model.predict(batch_size=batch_size) ===========================================
		for i in trange(warmup_steps, desc=f"Warmup for {model_name} (batch of {batch_size})"):
			_ = model.predict(sample, verbose=0, batch_size=batch_size)

		perf_callback.latency_ref.clear()
		for i in trange(repetitions, desc=f"Predict with bsize for {model_name} (batch of {batch_size})"):
			_ = model.predict(sample, verbose=0, callbacks=[perf_callback], batch_size=batch_size)

			telemetry['framework'].append("TF (batch_size=N)")
			telemetry['model_name'].append(model_name)
			telemetry['rep'].append(i)
			telemetry['batch_size'].append(batch_size)
		telemetry['elapsed_time'].extend(perf_callback.latency_ref)

		# model.predict_on_batch() =======================================================
		for i in trange(warmup_steps, desc=f"Warmup for {model_name} (batch of {batch_size})"):
			_ = model.predict_on_batch(sample)

		perf_callback.latency_ref.clear()
		for i in trange(repetitions, desc=f"Predict on batch for {model_name} (batch of {batch_size})"):
			perf_callback.on_predict_begin()  # tf api is a joke why predict_on_batch has no callbacks i hate it here
			_ = model.predict_on_batch(sample)
			perf_callback.on_predict_end()

			telemetry['framework'].append("TF (predict_on_batch)")
			telemetry['model_name'].append(model_name)
			telemetry['rep'].append(i)
			telemetry['batch_size'].append(batch_size)
		telemetry['elapsed_time'].extend(perf_callback.latency_ref)

		# model(x) =======================================================================
		for i in trange(warmup_steps, desc=f"Warmup for {model_name} (batch of {batch_size})"):
			_ = model(sample, training=False)

		perf_callback.latency_ref.clear()
		for i in trange(repetitions, desc=f"__call__ for {model_name} (batch of {batch_size})"):
			perf_callback.on_predict_begin()
			_ = model(sample, training=False)
			perf_callback.on_predict_end()

			telemetry['framework'].append("TF (__call__)")
			telemetry['model_name'].append(model_name)
			telemetry['rep'].append(i)
			telemetry['batch_size'].append(batch_size)
		telemetry['elapsed_time'].extend(perf_callback.latency_ref)

		del model
# Out:
# Warmup for FullyConnectedNet (batch of 1): 100%|██████████| 100/100 [00:07<00:00, 13.55it/s]
# Predict without bsize for FullyConnectedNet (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 18.73it/s]
# Warmup for FullyConnectedNet (batch of 1): 100%|██████████| 100/100 [00:04<00:00, 20.28it/s]
# Predict with bsize for FullyConnectedNet (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 20.18it/s]
# Warmup for FullyConnectedNet (batch of 1): 100%|██████████| 100/100 [00:00<00:00, 366.44it/s]
# Predict on batch for FullyConnectedNet (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 1220.92it/s]
# Warmup for FullyConnectedNet (batch of 1): 100%|██████████| 100/100 [00:00<00:00, 196.78it/s]
# __call__ for FullyConnectedNet (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 365.67it/s]
# Warmup for FullyConnectedNet (batch of 16): 100%|██████████| 100/100 [00:06<00:00, 14.86it/s]
# Predict without bsize for FullyConnectedNet (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 17.92it/s]
# Warmup for FullyConnectedNet (batch of 16): 100%|██████████| 100/100 [00:05<00:00, 19.86it/s]
# Predict with bsize for FullyConnectedNet (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 19.84it/s]
# Warmup for FullyConnectedNet (batch of 16): 100%|██████████| 100/100 [00:00<00:00, 315.07it/s]
# Predict on batch for FullyConnectedNet (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 1077.45it/s]
# Warmup for FullyConnectedNet (batch of 16): 100%|██████████| 100/100 [00:00<00:00, 392.75it/s]
# __call__ for FullyConnectedNet (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 380.75it/s]
# Warmup for FullyConnectedNet (batch of 32): 100%|██████████| 100/100 [00:06<00:00, 15.77it/s]
# Predict without bsize for FullyConnectedNet (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 20.32it/s]
# Warmup for FullyConnectedNet (batch of 32): 100%|██████████| 100/100 [00:04<00:00, 20.07it/s]
# Predict with bsize for FullyConnectedNet (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 19.71it/s]
# Warmup for FullyConnectedNet (batch of 32): 100%|██████████| 100/100 [00:00<00:00, 299.93it/s]
# Predict on batch for FullyConnectedNet (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 1089.64it/s]
# Warmup for FullyConnectedNet (batch of 32): 100%|██████████| 100/100 [00:00<00:00, 401.35it/s]
# __call__ for FullyConnectedNet (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 386.52it/s]
# Warmup for FullyConnectedNet (batch of 64): 100%|██████████| 100/100 [00:05<00:00, 17.38it/s]
# Predict without bsize for FullyConnectedNet (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 18.55it/s]
# Warmup for FullyConnectedNet (batch of 64): 100%|██████████| 100/100 [00:06<00:00, 15.18it/s]
# Predict with bsize for FullyConnectedNet (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 19.78it/s]
# Warmup for FullyConnectedNet (batch of 64): 100%|██████████| 100/100 [00:00<00:00, 310.36it/s]
# Predict on batch for FullyConnectedNet (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 999.77it/s]
# Warmup for FullyConnectedNet (batch of 64): 100%|██████████| 100/100 [00:00<00:00, 399.54it/s]
# __call__ for FullyConnectedNet (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 396.90it/s]
# Warmup for FullyConnectedNet (batch of 96): 100%|██████████| 100/100 [00:05<00:00, 17.26it/s]
# Predict without bsize for FullyConnectedNet (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 18.08it/s]
# Warmup for FullyConnectedNet (batch of 96): 100%|██████████| 100/100 [00:06<00:00, 15.36it/s]
# Predict with bsize for FullyConnectedNet (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 19.39it/s]
# Warmup for FullyConnectedNet (batch of 96): 100%|██████████| 100/100 [00:00<00:00, 295.18it/s]
# Predict on batch for FullyConnectedNet (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 944.19it/s]
# Warmup for FullyConnectedNet (batch of 96): 100%|██████████| 100/100 [00:00<00:00, 401.24it/s]
# __call__ for FullyConnectedNet (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 398.19it/s]
# Warmup for FullyConnectedNet (batch of 128): 100%|██████████| 100/100 [00:05<00:00, 17.21it/s]
# Predict without bsize for FullyConnectedNet (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 17.50it/s]
# Warmup for FullyConnectedNet (batch of 128): 100%|██████████| 100/100 [00:06<00:00, 15.37it/s]
# Predict with bsize for FullyConnectedNet (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 19.97it/s]
# Warmup for FullyConnectedNet (batch of 128): 100%|██████████| 100/100 [00:00<00:00, 302.99it/s]
# Predict on batch for FullyConnectedNet (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 875.56it/s]
# Warmup for FullyConnectedNet (batch of 128): 100%|██████████| 100/100 [00:00<00:00, 395.04it/s]
# __call__ for FullyConnectedNet (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 385.23it/s]
# Warmup for FullyConnectedNet (batch of 192): 100%|██████████| 100/100 [00:05<00:00, 17.05it/s]
# Predict without bsize for FullyConnectedNet (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 18.21it/s]
# Warmup for FullyConnectedNet (batch of 192): 100%|██████████| 100/100 [00:06<00:00, 15.70it/s]
# Predict with bsize for FullyConnectedNet (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 20.98it/s]
# Warmup for FullyConnectedNet (batch of 192): 100%|██████████| 100/100 [00:00<00:00, 268.07it/s]
# Predict on batch for FullyConnectedNet (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 855.89it/s]
# Warmup for FullyConnectedNet (batch of 192): 100%|██████████| 100/100 [00:00<00:00, 398.41it/s]
# __call__ for FullyConnectedNet (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 403.93it/s]
# Warmup for FullyConnectedNet (batch of 256): 100%|██████████| 100/100 [00:06<00:00, 16.55it/s]
# Predict without bsize for FullyConnectedNet (batch of 256): 100%|██████████| 50/50 [00:02<00:00, 16.95it/s]
# Warmup for FullyConnectedNet (batch of 256): 100%|██████████| 100/100 [00:06<00:00, 15.79it/s]
# Predict with bsize for FullyConnectedNet (batch of 256): 100%|██████████| 50/50 [00:02<00:00, 21.19it/s]
# Warmup for FullyConnectedNet (batch of 256): 100%|██████████| 100/100 [00:00<00:00, 265.48it/s]
# Predict on batch for FullyConnectedNet (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 740.53it/s]
# Warmup for FullyConnectedNet (batch of 256): 100%|██████████| 100/100 [00:00<00:00, 403.68it/s]
# __call__ for FullyConnectedNet (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 398.98it/s]
# Warmup for SimpleConvNet (batch of 1): 100%|██████████| 100/100 [00:06<00:00, 15.18it/s]
# Predict without bsize for SimpleConvNet (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 18.67it/s]
# Warmup for SimpleConvNet (batch of 1): 100%|██████████| 100/100 [00:04<00:00, 20.75it/s]
# Predict with bsize for SimpleConvNet (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 20.46it/s]
# Warmup for SimpleConvNet (batch of 1): 100%|██████████| 100/100 [00:00<00:00, 269.67it/s]
# Predict on batch for SimpleConvNet (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 1082.35it/s]
# Warmup for SimpleConvNet (batch of 1): 100%|██████████| 100/100 [00:00<00:00, 114.61it/s]
# __call__ for SimpleConvNet (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 149.28it/s]
# Warmup for SimpleConvNet (batch of 16): 100%|██████████| 100/100 [00:06<00:00, 15.10it/s]
# Predict without bsize for SimpleConvNet (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 18.85it/s]
# Warmup for SimpleConvNet (batch of 16): 100%|██████████| 100/100 [00:04<00:00, 21.29it/s]
# Predict with bsize for SimpleConvNet (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 21.38it/s]
# Warmup for SimpleConvNet (batch of 16): 100%|██████████| 100/100 [00:00<00:00, 131.71it/s]
# Predict on batch for SimpleConvNet (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 1018.65it/s]
# Warmup for SimpleConvNet (batch of 16): 100%|██████████| 100/100 [00:00<00:00, 143.38it/s]
# __call__ for SimpleConvNet (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 153.80it/s]
# Warmup for SimpleConvNet (batch of 32): 100%|██████████| 100/100 [00:06<00:00, 15.54it/s]
# Predict without bsize for SimpleConvNet (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 21.40it/s]
# Warmup for SimpleConvNet (batch of 32): 100%|██████████| 100/100 [00:04<00:00, 21.13it/s]
# Predict with bsize for SimpleConvNet (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 20.85it/s]
# Warmup for SimpleConvNet (batch of 32): 100%|██████████| 100/100 [00:00<00:00, 115.03it/s]
# Predict on batch for SimpleConvNet (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 938.74it/s]
# Warmup for SimpleConvNet (batch of 32): 100%|██████████| 100/100 [00:00<00:00, 144.73it/s]
# __call__ for SimpleConvNet (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 152.05it/s]
# Warmup for SimpleConvNet (batch of 64): 100%|██████████| 100/100 [00:05<00:00, 18.06it/s]
# Predict without bsize for SimpleConvNet (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 19.49it/s]
# Warmup for SimpleConvNet (batch of 64): 100%|██████████| 100/100 [00:06<00:00, 15.55it/s]
# Predict with bsize for SimpleConvNet (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 21.26it/s]
# Warmup for SimpleConvNet (batch of 64): 100%|██████████| 100/100 [00:00<00:00, 130.03it/s]
# Predict on batch for SimpleConvNet (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 871.50it/s]
# Warmup for SimpleConvNet (batch of 64): 100%|██████████| 100/100 [00:00<00:00, 141.78it/s]
# __call__ for SimpleConvNet (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 155.15it/s]
# Warmup for SimpleConvNet (batch of 96): 100%|██████████| 100/100 [00:05<00:00, 17.46it/s]
# Predict without bsize for SimpleConvNet (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 19.45it/s]
# Warmup for SimpleConvNet (batch of 96): 100%|██████████| 100/100 [00:06<00:00, 15.51it/s]
# Predict with bsize for SimpleConvNet (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 21.58it/s]
# Warmup for SimpleConvNet (batch of 96): 100%|██████████| 100/100 [00:00<00:00, 130.60it/s]
# Predict on batch for SimpleConvNet (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 843.62it/s]
# Warmup for SimpleConvNet (batch of 96): 100%|██████████| 100/100 [00:00<00:00, 141.69it/s]
# __call__ for SimpleConvNet (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 151.37it/s]
# Warmup for SimpleConvNet (batch of 128): 100%|██████████| 100/100 [00:05<00:00, 17.02it/s]
# Predict without bsize for SimpleConvNet (batch of 128): 100%|██████████| 50/50 [00:03<00:00, 16.38it/s]
# Warmup for SimpleConvNet (batch of 128): 100%|██████████| 100/100 [00:06<00:00, 15.65it/s]
# Predict with bsize for SimpleConvNet (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 20.39it/s]
# Warmup for SimpleConvNet (batch of 128): 100%|██████████| 100/100 [00:00<00:00, 231.38it/s]
# Predict on batch for SimpleConvNet (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 778.54it/s]
# Warmup for SimpleConvNet (batch of 128): 100%|██████████| 100/100 [00:00<00:00, 138.57it/s]
# __call__ for SimpleConvNet (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 151.66it/s]
# Warmup for SimpleConvNet (batch of 192): 100%|██████████| 100/100 [00:06<00:00, 15.77it/s]
# Predict without bsize for SimpleConvNet (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 17.36it/s]
# Warmup for SimpleConvNet (batch of 192): 100%|██████████| 100/100 [00:06<00:00, 15.24it/s]
# Predict with bsize for SimpleConvNet (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 20.35it/s]
# Warmup for SimpleConvNet (batch of 192): 100%|██████████| 100/100 [00:00<00:00, 225.92it/s]
# Predict on batch for SimpleConvNet (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 748.85it/s]
# Warmup for SimpleConvNet (batch of 192): 100%|██████████| 100/100 [00:00<00:00, 142.35it/s]
# __call__ for SimpleConvNet (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 151.14it/s]
# Warmup for SimpleConvNet (batch of 256): 100%|██████████| 100/100 [00:06<00:00, 15.16it/s]
# Predict without bsize for SimpleConvNet (batch of 256): 100%|██████████| 50/50 [00:03<00:00, 16.11it/s]
# Warmup for SimpleConvNet (batch of 256): 100%|██████████| 100/100 [00:06<00:00, 14.88it/s]
# Predict with bsize for SimpleConvNet (batch of 256): 100%|██████████| 50/50 [00:02<00:00, 21.11it/s]
# Warmup for SimpleConvNet (batch of 256): 100%|██████████| 100/100 [00:00<00:00, 110.93it/s]
# Predict on batch for SimpleConvNet (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 684.71it/s]
# Warmup for SimpleConvNet (batch of 256): 100%|██████████| 100/100 [00:00<00:00, 139.15it/s]
# __call__ for SimpleConvNet (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 151.47it/s]
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 18s 0us/step
# Warmup for ResNet-50 (batch of 1): 100%|██████████| 100/100 [00:09<00:00, 10.59it/s]
# Predict without bsize for ResNet-50 (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 18.61it/s]
# Warmup for ResNet-50 (batch of 1): 100%|██████████| 100/100 [00:04<00:00, 20.03it/s]
# Predict with bsize for ResNet-50 (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 17.04it/s]
# Warmup for ResNet-50 (batch of 1): 100%|██████████| 100/100 [00:03<00:00, 29.28it/s]
# Predict on batch for ResNet-50 (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 231.42it/s]
# Warmup for ResNet-50 (batch of 1): 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# __call__ for ResNet-50 (batch of 1): 100%|██████████| 50/50 [00:10<00:00,  4.95it/s]
# Warmup for ResNet-50 (batch of 16): 100%|██████████| 100/100 [00:09<00:00, 10.01it/s]
# Predict without bsize for ResNet-50 (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 18.35it/s]
# Warmup for ResNet-50 (batch of 16): 100%|██████████| 100/100 [00:04<00:00, 20.26it/s]
# Predict with bsize for ResNet-50 (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 20.03it/s]
# Warmup for ResNet-50 (batch of 16): 100%|██████████| 100/100 [00:03<00:00, 28.09it/s]
# Predict on batch for ResNet-50 (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 242.74it/s]
# Warmup for ResNet-50 (batch of 16): 100%|██████████| 100/100 [00:20<00:00,  4.86it/s]
# __call__ for ResNet-50 (batch of 16): 100%|██████████| 50/50 [00:10<00:00,  4.93it/s]
# Warmup for ResNet-50 (batch of 32): 100%|██████████| 100/100 [00:10<00:00,  9.90it/s]
# Predict without bsize for ResNet-50 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 19.50it/s]
# Warmup for ResNet-50 (batch of 32): 100%|██████████| 100/100 [00:05<00:00, 19.18it/s]
# Predict with bsize for ResNet-50 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 19.27it/s]
# Warmup for ResNet-50 (batch of 32): 100%|██████████| 100/100 [00:03<00:00, 29.02it/s]
# Predict on batch for ResNet-50 (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 242.60it/s]
# Warmup for ResNet-50 (batch of 32): 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# __call__ for ResNet-50 (batch of 32): 100%|██████████| 50/50 [00:10<00:00,  4.90it/s]
# Warmup for ResNet-50 (batch of 64): 100%|██████████| 100/100 [00:08<00:00, 11.63it/s]
# Predict without bsize for ResNet-50 (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 17.13it/s]
# Warmup for ResNet-50 (batch of 64): 100%|██████████| 100/100 [00:09<00:00, 10.09it/s]
# Predict with bsize for ResNet-50 (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 19.48it/s]
# Warmup for ResNet-50 (batch of 64): 100%|██████████| 100/100 [00:03<00:00, 28.87it/s]
# Predict on batch for ResNet-50 (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 233.25it/s]
# Warmup for ResNet-50 (batch of 64): 100%|██████████| 100/100 [00:20<00:00,  4.87it/s]
# __call__ for ResNet-50 (batch of 64): 100%|██████████| 50/50 [00:10<00:00,  4.96it/s]
# Warmup for ResNet-50 (batch of 96): 100%|██████████| 100/100 [00:09<00:00, 10.60it/s]
# Predict without bsize for ResNet-50 (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 15.51it/s]
# Warmup for ResNet-50 (batch of 96): 100%|██████████| 100/100 [00:10<00:00,  9.72it/s]
# Predict with bsize for ResNet-50 (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 19.33it/s]
# Warmup for ResNet-50 (batch of 96): 100%|██████████| 100/100 [00:03<00:00, 27.55it/s]
# Predict on batch for ResNet-50 (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 219.20it/s]
# Warmup for ResNet-50 (batch of 96): 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# __call__ for ResNet-50 (batch of 96): 100%|██████████| 50/50 [00:10<00:00,  4.93it/s]
# Warmup for ResNet-50 (batch of 128): 100%|██████████| 100/100 [00:09<00:00, 10.45it/s]
# Predict without bsize for ResNet-50 (batch of 128): 100%|██████████| 50/50 [00:03<00:00, 15.13it/s]
# Warmup for ResNet-50 (batch of 128): 100%|██████████| 100/100 [00:11<00:00,  8.85it/s]
# Predict with bsize for ResNet-50 (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 18.64it/s]
# Warmup for ResNet-50 (batch of 128): 100%|██████████| 100/100 [00:03<00:00, 26.87it/s]
# Predict on batch for ResNet-50 (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 211.97it/s]
# Warmup for ResNet-50 (batch of 128): 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# __call__ for ResNet-50 (batch of 128): 100%|██████████| 50/50 [00:10<00:00,  4.88it/s]
# Warmup for ResNet-50 (batch of 192): 100%|██████████| 100/100 [00:10<00:00,  9.23it/s]
# Predict without bsize for ResNet-50 (batch of 192): 100%|██████████| 50/50 [00:03<00:00, 12.77it/s]
# Warmup for ResNet-50 (batch of 192): 100%|██████████| 100/100 [00:10<00:00,  9.87it/s]
# Predict with bsize for ResNet-50 (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 19.00it/s]
# Warmup for ResNet-50 (batch of 192): 100%|██████████| 100/100 [00:03<00:00, 28.18it/s]
# Predict on batch for ResNet-50 (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 200.36it/s]
# Warmup for ResNet-50 (batch of 192): 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# __call__ for ResNet-50 (batch of 192): 100%|██████████| 50/50 [00:10<00:00,  4.87it/s]
# Warmup for ResNet-50 (batch of 256): 100%|██████████| 100/100 [00:12<00:00,  8.04it/s]
# Predict without bsize for ResNet-50 (batch of 256): 100%|██████████| 50/50 [00:04<00:00, 11.14it/s]
# Warmup for ResNet-50 (batch of 256): 100%|██████████| 100/100 [00:10<00:00,  9.53it/s]
# Predict with bsize for ResNet-50 (batch of 256): 100%|██████████| 50/50 [00:02<00:00, 18.02it/s]
# Warmup for ResNet-50 (batch of 256): 100%|██████████| 100/100 [00:03<00:00, 28.02it/s]
# Predict on batch for ResNet-50 (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 186.95it/s]
# Warmup for ResNet-50 (batch of 256): 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# __call__ for ResNet-50 (batch of 256): 100%|██████████| 50/50 [00:10<00:00,  4.92it/s]
# Warmup for DenseNet-121 (batch of 1): 100%|██████████| 100/100 [00:15<00:00,  6.26it/s]
# Predict without bsize for DenseNet-121 (batch of 1): 100%|██████████| 50/50 [00:03<00:00, 16.53it/s]
# Warmup for DenseNet-121 (batch of 1): 100%|██████████| 100/100 [00:07<00:00, 14.23it/s]
# Predict with bsize for DenseNet-121 (batch of 1): 100%|██████████| 50/50 [00:03<00:00, 16.43it/s]
# Warmup for DenseNet-121 (batch of 1): 100%|██████████| 100/100 [00:07<00:00, 12.64it/s]
# Predict on batch for DenseNet-121 (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 131.58it/s]
# Warmup for DenseNet-121 (batch of 1): 100%|██████████| 100/100 [00:41<00:00,  2.40it/s]
# __call__ for DenseNet-121 (batch of 1): 100%|██████████| 50/50 [00:20<00:00,  2.39it/s]
# Warmup for DenseNet-121 (batch of 16): 100%|██████████| 100/100 [00:17<00:00,  5.81it/s]
# Predict without bsize for DenseNet-121 (batch of 16): 100%|██████████| 50/50 [00:03<00:00, 15.77it/s]
# Warmup for DenseNet-121 (batch of 16): 100%|██████████| 100/100 [00:05<00:00, 17.07it/s]
# Predict with bsize for DenseNet-121 (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 16.98it/s]
# Warmup for DenseNet-121 (batch of 16): 100%|██████████| 100/100 [00:08<00:00, 11.16it/s]
# Predict on batch for DenseNet-121 (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 120.11it/s]
# Warmup for DenseNet-121 (batch of 16): 100%|██████████| 100/100 [00:42<00:00,  2.37it/s]
# __call__ for DenseNet-121 (batch of 16): 100%|██████████| 50/50 [00:20<00:00,  2.39it/s]
# Warmup for DenseNet-121 (batch of 32): 100%|██████████| 100/100 [00:16<00:00,  5.91it/s]
# Predict without bsize for DenseNet-121 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 16.92it/s]
# Warmup for DenseNet-121 (batch of 32): 100%|██████████| 100/100 [00:05<00:00, 16.96it/s]
# Predict with bsize for DenseNet-121 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 16.83it/s]
# Warmup for DenseNet-121 (batch of 32): 100%|██████████| 100/100 [00:07<00:00, 12.87it/s]
# Predict on batch for DenseNet-121 (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 120.49it/s]
# Warmup for DenseNet-121 (batch of 32): 100%|██████████| 100/100 [00:42<00:00,  2.37it/s]
# __call__ for DenseNet-121 (batch of 32): 100%|██████████| 50/50 [00:20<00:00,  2.38it/s]
# Warmup for DenseNet-121 (batch of 64): 100%|██████████| 100/100 [00:14<00:00,  6.88it/s]
# Predict without bsize for DenseNet-121 (batch of 64): 100%|██████████| 50/50 [00:03<00:00, 13.86it/s]
# Warmup for DenseNet-121 (batch of 64): 100%|██████████| 100/100 [00:17<00:00,  5.77it/s]
# Predict with bsize for DenseNet-121 (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 17.11it/s]
# Warmup for DenseNet-121 (batch of 64): 100%|██████████| 100/100 [00:08<00:00, 12.49it/s]
# Predict on batch for DenseNet-121 (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 115.99it/s]
# Warmup for DenseNet-121 (batch of 64): 100%|██████████| 100/100 [00:42<00:00,  2.37it/s]
# __call__ for DenseNet-121 (batch of 64): 100%|██████████| 50/50 [00:21<00:00,  2.37it/s]
# Warmup for DenseNet-121 (batch of 96): 100%|██████████| 100/100 [00:15<00:00,  6.49it/s]
# Predict without bsize for DenseNet-121 (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 12.51it/s]
# Warmup for DenseNet-121 (batch of 96): 100%|██████████| 100/100 [00:17<00:00,  5.73it/s]
# Predict with bsize for DenseNet-121 (batch of 96): 100%|██████████| 50/50 [00:02<00:00, 17.03it/s]
# Warmup for DenseNet-121 (batch of 96): 100%|██████████| 100/100 [00:07<00:00, 12.75it/s]
# Predict on batch for DenseNet-121 (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 130.39it/s]
# Warmup for DenseNet-121 (batch of 96): 100%|██████████| 100/100 [00:42<00:00,  2.36it/s]
# __call__ for DenseNet-121 (batch of 96): 100%|██████████| 50/50 [00:21<00:00,  2.38it/s]
# Warmup for DenseNet-121 (batch of 128): 100%|██████████| 100/100 [00:15<00:00,  6.40it/s]
# Predict without bsize for DenseNet-121 (batch of 128): 100%|██████████| 50/50 [00:04<00:00, 11.49it/s]
# Warmup for DenseNet-121 (batch of 128): 100%|██████████| 100/100 [00:20<00:00,  4.99it/s]
# Predict with bsize for DenseNet-121 (batch of 128): 100%|██████████| 50/50 [00:03<00:00, 15.51it/s]
# Warmup for DenseNet-121 (batch of 128): 100%|██████████| 100/100 [00:08<00:00, 11.93it/s]
# Predict on batch for DenseNet-121 (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 123.85it/s]
# Warmup for DenseNet-121 (batch of 128): 100%|██████████| 100/100 [00:42<00:00,  2.36it/s]
# __call__ for DenseNet-121 (batch of 128): 100%|██████████| 50/50 [00:21<00:00,  2.37it/s]
# Warmup for DenseNet-121 (batch of 192): 100%|██████████| 100/100 [00:17<00:00,  5.58it/s]
# Predict without bsize for DenseNet-121 (batch of 192): 100%|██████████| 50/50 [00:05<00:00,  9.11it/s]
# Warmup for DenseNet-121 (batch of 192): 100%|██████████| 100/100 [00:17<00:00,  5.62it/s]
# Predict with bsize for DenseNet-121 (batch of 192): 100%|██████████| 50/50 [00:03<00:00, 16.15it/s]
# Warmup for DenseNet-121 (batch of 192): 100%|██████████| 100/100 [00:09<00:00, 10.22it/s]
# Predict on batch for DenseNet-121 (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 112.58it/s]
# Warmup for DenseNet-121 (batch of 192): 100%|██████████| 100/100 [00:42<00:00,  2.36it/s]
# __call__ for DenseNet-121 (batch of 192): 100%|██████████| 50/50 [00:21<00:00,  2.37it/s]
# Warmup for DenseNet-121 (batch of 256): 100%|██████████| 100/100 [00:20<00:00,  4.98it/s]
# Predict without bsize for DenseNet-121 (batch of 256): 100%|██████████| 50/50 [00:06<00:00,  7.64it/s]
# Warmup for DenseNet-121 (batch of 256): 100%|██████████| 100/100 [00:18<00:00,  5.51it/s]
# Predict with bsize for DenseNet-121 (batch of 256): 100%|██████████| 50/50 [00:03<00:00, 15.96it/s]
# Warmup for DenseNet-121 (batch of 256): 100%|██████████| 100/100 [00:08<00:00, 12.40it/s]
# Predict on batch for DenseNet-121 (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 101.10it/s]
# Warmup for DenseNet-121 (batch of 256): 100%|██████████| 100/100 [00:42<00:00,  2.36it/s]
# __call__ for DenseNet-121 (batch of 256): 100%|██████████| 50/50 [00:21<00:00,  2.37it/s]
# Warmup for MobileNet-v2 (batch of 1): 100%|██████████| 100/100 [00:08<00:00, 11.29it/s]
# Predict without bsize for MobileNet-v2 (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 17.14it/s]
# Warmup for MobileNet-v2 (batch of 1): 100%|██████████| 100/100 [00:07<00:00, 13.74it/s]
# Predict with bsize for MobileNet-v2 (batch of 1): 100%|██████████| 50/50 [00:03<00:00, 15.13it/s]
# Warmup for MobileNet-v2 (batch of 1): 100%|██████████| 100/100 [00:03<00:00, 33.13it/s]
# Predict on batch for MobileNet-v2 (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 284.35it/s]
# Warmup for MobileNet-v2 (batch of 1): 100%|██████████| 100/100 [00:13<00:00,  7.25it/s]
# __call__ for MobileNet-v2 (batch of 1): 100%|██████████| 50/50 [00:06<00:00,  7.31it/s]
# Warmup for MobileNet-v2 (batch of 16): 100%|██████████| 100/100 [00:09<00:00, 10.09it/s]
# Predict without bsize for MobileNet-v2 (batch of 16): 100%|██████████| 50/50 [00:03<00:00, 15.27it/s]
# Warmup for MobileNet-v2 (batch of 16): 100%|██████████| 100/100 [00:05<00:00, 17.50it/s]
# Predict with bsize for MobileNet-v2 (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 17.68it/s]
# Warmup for MobileNet-v2 (batch of 16): 100%|██████████| 100/100 [00:02<00:00, 36.61it/s]
# Predict on batch for MobileNet-v2 (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 241.78it/s]
# Warmup for MobileNet-v2 (batch of 16): 100%|██████████| 100/100 [00:13<00:00,  7.33it/s]
# __call__ for MobileNet-v2 (batch of 16): 100%|██████████| 50/50 [00:06<00:00,  7.36it/s]
# Warmup for MobileNet-v2 (batch of 32): 100%|██████████| 100/100 [00:08<00:00, 11.35it/s]
# Predict without bsize for MobileNet-v2 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 18.44it/s]
# Warmup for MobileNet-v2 (batch of 32): 100%|██████████| 100/100 [00:05<00:00, 17.78it/s]
# Predict with bsize for MobileNet-v2 (batch of 32): 100%|██████████| 50/50 [00:02<00:00, 18.12it/s]
# Warmup for MobileNet-v2 (batch of 32): 100%|██████████| 100/100 [00:02<00:00, 37.84it/s]
# Predict on batch for MobileNet-v2 (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 263.27it/s]
# Warmup for MobileNet-v2 (batch of 32): 100%|██████████| 100/100 [00:13<00:00,  7.39it/s]
# __call__ for MobileNet-v2 (batch of 32): 100%|██████████| 50/50 [00:06<00:00,  7.35it/s]
# Warmup for MobileNet-v2 (batch of 64): 100%|██████████| 100/100 [00:08<00:00, 11.81it/s]
# Predict without bsize for MobileNet-v2 (batch of 64): 100%|██████████| 50/50 [00:03<00:00, 16.16it/s]
# Warmup for MobileNet-v2 (batch of 64): 100%|██████████| 100/100 [00:08<00:00, 11.34it/s]
# Predict with bsize for MobileNet-v2 (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 18.36it/s]
# Warmup for MobileNet-v2 (batch of 64): 100%|██████████| 100/100 [00:02<00:00, 38.19it/s]
# Predict on batch for MobileNet-v2 (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 271.18it/s]
# Warmup for MobileNet-v2 (batch of 64): 100%|██████████| 100/100 [00:13<00:00,  7.38it/s]
# __call__ for MobileNet-v2 (batch of 64): 100%|██████████| 50/50 [00:06<00:00,  7.37it/s]
# Warmup for MobileNet-v2 (batch of 96): 100%|██████████| 100/100 [00:10<00:00,  9.11it/s]
# Predict without bsize for MobileNet-v2 (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 13.02it/s]
# Warmup for MobileNet-v2 (batch of 96): 100%|██████████| 100/100 [00:10<00:00,  9.85it/s]
# Predict with bsize for MobileNet-v2 (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 16.54it/s]
# Warmup for MobileNet-v2 (batch of 96): 100%|██████████| 100/100 [00:02<00:00, 35.67it/s]
# Predict on batch for MobileNet-v2 (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 251.35it/s]
# Warmup for MobileNet-v2 (batch of 96): 100%|██████████| 100/100 [00:13<00:00,  7.27it/s]
# __call__ for MobileNet-v2 (batch of 96): 100%|██████████| 50/50 [00:06<00:00,  7.29it/s]
# Warmup for MobileNet-v2 (batch of 128): 100%|██████████| 100/100 [00:09<00:00, 10.16it/s]
# Predict without bsize for MobileNet-v2 (batch of 128): 100%|██████████| 50/50 [00:03<00:00, 13.53it/s]
# Warmup for MobileNet-v2 (batch of 128): 100%|██████████| 100/100 [00:09<00:00, 10.57it/s]
# Predict with bsize for MobileNet-v2 (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 17.75it/s]
# Warmup for MobileNet-v2 (batch of 128): 100%|██████████| 100/100 [00:02<00:00, 38.09it/s]
# Predict on batch for MobileNet-v2 (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 245.63it/s]
# Warmup for MobileNet-v2 (batch of 128): 100%|██████████| 100/100 [00:13<00:00,  7.34it/s]
# __call__ for MobileNet-v2 (batch of 128): 100%|██████████| 50/50 [00:06<00:00,  7.37it/s]
# Warmup for MobileNet-v2 (batch of 192): 100%|██████████| 100/100 [00:10<00:00,  9.97it/s]
# Predict without bsize for MobileNet-v2 (batch of 192): 100%|██████████| 50/50 [00:04<00:00, 12.43it/s]
# Warmup for MobileNet-v2 (batch of 192): 100%|██████████| 100/100 [00:09<00:00, 10.93it/s]
# Predict with bsize for MobileNet-v2 (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 17.94it/s]
# Warmup for MobileNet-v2 (batch of 192): 100%|██████████| 100/100 [00:02<00:00, 38.50it/s]
# Predict on batch for MobileNet-v2 (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 268.41it/s]
# Warmup for MobileNet-v2 (batch of 192): 100%|██████████| 100/100 [00:13<00:00,  7.38it/s]
# __call__ for MobileNet-v2 (batch of 192): 100%|██████████| 50/50 [00:06<00:00,  7.38it/s]
# Warmup for MobileNet-v2 (batch of 256): 100%|██████████| 100/100 [00:10<00:00,  9.22it/s]
# Predict without bsize for MobileNet-v2 (batch of 256): 100%|██████████| 50/50 [00:04<00:00, 11.41it/s]
# Warmup for MobileNet-v2 (batch of 256): 100%|██████████| 100/100 [00:10<00:00,  9.70it/s]
# Predict with bsize for MobileNet-v2 (batch of 256): 100%|██████████| 50/50 [00:03<00:00, 15.04it/s]
# Warmup for MobileNet-v2 (batch of 256): 100%|██████████| 100/100 [00:03<00:00, 32.07it/s]
# Predict on batch for MobileNet-v2 (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 261.00it/s]
# Warmup for MobileNet-v2 (batch of 256): 100%|██████████| 100/100 [00:13<00:00,  7.35it/s]
# __call__ for MobileNet-v2 (batch of 256): 100%|██████████| 50/50 [00:06<00:00,  7.40it/s]
# Warmup for ConvNeXt-Tiny (batch of 1): 100%|██████████| 100/100 [00:09<00:00, 10.73it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 1): 100%|██████████| 50/50 [00:03<00:00, 16.41it/s]
# Warmup for ConvNeXt-Tiny (batch of 1): 100%|██████████| 100/100 [00:05<00:00, 17.91it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 1): 100%|██████████| 50/50 [00:02<00:00, 17.43it/s]
# Warmup for ConvNeXt-Tiny (batch of 1): 100%|██████████| 100/100 [00:02<00:00, 33.94it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 1): 100%|██████████| 50/50 [00:00<00:00, 307.82it/s]
# Warmup for ConvNeXt-Tiny (batch of 1):   0%|          | 0/100 [00:00<?, ?it/s]WARNING:tensorflow:5 out of the last 5 calls to <function conv.<locals>._conv_xla at 0x7d383177b6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function conv.<locals>._conv_xla at 0x7d383177b560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Warmup for ConvNeXt-Tiny (batch of 1): 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# __call__ for ConvNeXt-Tiny (batch of 1): 100%|██████████| 50/50 [00:45<00:00,  1.10it/s]
# Warmup for ConvNeXt-Tiny (batch of 16): 100%|██████████| 100/100 [00:13<00:00,  7.18it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 17.41it/s]
# Warmup for ConvNeXt-Tiny (batch of 16): 100%|██████████| 100/100 [00:05<00:00, 19.14it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 16): 100%|██████████| 50/50 [00:02<00:00, 18.90it/s]
# Warmup for ConvNeXt-Tiny (batch of 16): 100%|██████████| 100/100 [00:03<00:00, 31.38it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 16): 100%|██████████| 50/50 [00:00<00:00, 306.85it/s]
# Warmup for ConvNeXt-Tiny (batch of 16): 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]
# __call__ for ConvNeXt-Tiny (batch of 16): 100%|██████████| 50/50 [00:47<00:00,  1.06it/s]
# Warmup for ConvNeXt-Tiny (batch of 32): 100%|██████████| 100/100 [00:14<00:00,  6.73it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 32): 100%|██████████| 50/50 [00:03<00:00, 15.60it/s]
# Warmup for ConvNeXt-Tiny (batch of 32): 100%|██████████| 100/100 [00:06<00:00, 15.50it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 32): 100%|██████████| 50/50 [00:03<00:00, 15.90it/s]
# Warmup for ConvNeXt-Tiny (batch of 32): 100%|██████████| 100/100 [00:03<00:00, 28.32it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 32): 100%|██████████| 50/50 [00:00<00:00, 292.88it/s]
# Warmup for ConvNeXt-Tiny (batch of 32): 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# __call__ for ConvNeXt-Tiny (batch of 32): 100%|██████████| 50/50 [00:47<00:00,  1.05it/s]
# Warmup for ConvNeXt-Tiny (batch of 64): 100%|██████████| 100/100 [00:08<00:00, 11.47it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 16.88it/s]
# Warmup for ConvNeXt-Tiny (batch of 64): 100%|██████████| 100/100 [00:13<00:00,  7.57it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 64): 100%|██████████| 50/50 [00:02<00:00, 18.88it/s]
# Warmup for ConvNeXt-Tiny (batch of 64): 100%|██████████| 100/100 [00:03<00:00, 30.69it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 64): 100%|██████████| 50/50 [00:00<00:00, 305.27it/s]
# Warmup for ConvNeXt-Tiny (batch of 64): 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# __call__ for ConvNeXt-Tiny (batch of 64): 100%|██████████| 50/50 [00:47<00:00,  1.06it/s]
# Warmup for ConvNeXt-Tiny (batch of 96): 100%|██████████| 100/100 [00:09<00:00, 10.91it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 15.79it/s]
# Warmup for ConvNeXt-Tiny (batch of 96): 100%|██████████| 100/100 [00:15<00:00,  6.58it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 96): 100%|██████████| 50/50 [00:03<00:00, 15.20it/s]
# Warmup for ConvNeXt-Tiny (batch of 96): 100%|██████████| 100/100 [00:03<00:00, 26.02it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 96): 100%|██████████| 50/50 [00:00<00:00, 267.82it/s]
# Warmup for ConvNeXt-Tiny (batch of 96): 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# __call__ for ConvNeXt-Tiny (batch of 96): 100%|██████████| 50/50 [00:47<00:00,  1.06it/s]
# Warmup for ConvNeXt-Tiny (batch of 128): 100%|██████████| 100/100 [00:09<00:00, 10.34it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 128): 100%|██████████| 50/50 [00:03<00:00, 14.85it/s]
# Warmup for ConvNeXt-Tiny (batch of 128): 100%|██████████| 100/100 [00:13<00:00,  7.28it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 128): 100%|██████████| 50/50 [00:02<00:00, 18.58it/s]
# Warmup for ConvNeXt-Tiny (batch of 128): 100%|██████████| 100/100 [00:03<00:00, 30.38it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 128): 100%|██████████| 50/50 [00:00<00:00, 269.59it/s]
# Warmup for ConvNeXt-Tiny (batch of 128): 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]
# __call__ for ConvNeXt-Tiny (batch of 128): 100%|██████████| 50/50 [00:47<00:00,  1.06it/s]
# Warmup for ConvNeXt-Tiny (batch of 192): 100%|██████████| 100/100 [00:10<00:00,  9.62it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 192): 100%|██████████| 50/50 [00:03<00:00, 12.97it/s]
# Warmup for ConvNeXt-Tiny (batch of 192): 100%|██████████| 100/100 [00:13<00:00,  7.34it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 192): 100%|██████████| 50/50 [00:02<00:00, 18.44it/s]
# Warmup for ConvNeXt-Tiny (batch of 192): 100%|██████████| 100/100 [00:03<00:00, 30.23it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 192): 100%|██████████| 50/50 [00:00<00:00, 246.62it/s]
# Warmup for ConvNeXt-Tiny (batch of 192): 100%|██████████| 100/100 [01:39<00:00,  1.01it/s]
# __call__ for ConvNeXt-Tiny (batch of 192): 100%|██████████| 50/50 [00:48<00:00,  1.03it/s]
# Warmup for ConvNeXt-Tiny (batch of 256): 100%|██████████| 100/100 [00:11<00:00,  8.98it/s]
# Predict without bsize for ConvNeXt-Tiny (batch of 256): 100%|██████████| 50/50 [00:04<00:00, 11.94it/s]
# Warmup for ConvNeXt-Tiny (batch of 256): 100%|██████████| 100/100 [00:13<00:00,  7.17it/s]
# Predict with bsize for ConvNeXt-Tiny (batch of 256): 100%|██████████| 50/50 [00:02<00:00, 18.27it/s]
# Warmup for ConvNeXt-Tiny (batch of 256): 100%|██████████| 100/100 [00:03<00:00, 30.13it/s]
# Predict on batch for ConvNeXt-Tiny (batch of 256): 100%|██████████| 50/50 [00:00<00:00, 224.47it/s]
# Warmup for ConvNeXt-Tiny (batch of 256): 100%|██████████| 100/100 [01:37<00:00,  1.03it/s]
# __call__ for ConvNeXt-Tiny (batch of 256): 100%|██████████| 50/50 [00:48<00:00,  1.03it/s]

# %%
results = pd.DataFrame(telemetry)

if second_run:
	first_part = pd.read_csv(f"./drive/MyDrive/colab/results/tensorflow-batch-size-comp-{INDEX}.csv")
	results = pd.concat([first_part, results])

results.to_csv(f"./drive/MyDrive/colab/results/tensorflow-batch-size-comp-{INDEX}.csv", index=False)

# %%
results = results.drop(["rep"], axis=1)
display(results.head())

results = results.groupby(["framework", "model_name", "batch_size"])
results.mean().head(15).reset_index()
# Out:
#               framework         model_name  batch_size  elapsed_time
# 0  TF (batch_size=None)  FullyConnectedNet           1      17255356
# 1  TF (batch_size=None)  FullyConnectedNet           1      18254394
# 2  TF (batch_size=None)  FullyConnectedNet           1      18136394
# 3  TF (batch_size=None)  FullyConnectedNet           1      18133692
# 4  TF (batch_size=None)  FullyConnectedNet           1      18454136
#         framework     model_name  batch_size  elapsed_time
# 0   TF (__call__)  ConvNeXt-Tiny           1  9.116833e+08
# 1   TF (__call__)  ConvNeXt-Tiny          16  9.407791e+08
# 2   TF (__call__)  ConvNeXt-Tiny          32  9.486652e+08
# 3   TF (__call__)  ConvNeXt-Tiny          64  9.446010e+08
# 4   TF (__call__)  ConvNeXt-Tiny          96  9.419185e+08
# 5   TF (__call__)  ConvNeXt-Tiny         128  9.449198e+08
# 6   TF (__call__)  ConvNeXt-Tiny         192  9.697458e+08
# 7   TF (__call__)  ConvNeXt-Tiny         256  9.714079e+08
# 8   TF (__call__)   DenseNet-121           1  4.167878e+08
# 9   TF (__call__)   DenseNet-121          16  4.170987e+08
# 10  TF (__call__)   DenseNet-121          32  4.184800e+08
# 11  TF (__call__)   DenseNet-121          64  4.198981e+08
# 12  TF (__call__)   DenseNet-121          96  4.190494e+08
# 13  TF (__call__)   DenseNet-121         128  4.211541e+08
# 14  TF (__call__)   DenseNet-121         192  4.215878e+08

# %%
model, ds, _ = env_builder(model_name, config)
